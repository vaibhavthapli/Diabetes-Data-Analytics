# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 =pd.read_csv("C:\\Users\\croma\\Dexlab python\\python\\Custom_Diabetes_Dataset (1).csv")
df1
# Out:
#      pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0              6             148              72                      35
# 1              1              85              66                      29
# 2              8             183              64                       0
# 3              1              89              66                      23
# 4              0             137              40                      35
# 5              5             116              74                       0
# 6              3              78              50                      32
# 7             10             115               0                       0
# 8              2             197              70                      45
# 9              8             125              96                       0
# 10             4             110              92                       0
# 11            10             168              74                       0
# ...

# %%
df1.head()
# Out:
#    pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0            6             148              72                      35
# 1            1              85              66                      29
# 2            8             183              64                       0
# 3            1              89              66                      23
# 4            0             137              40                      35
#
#    insulin   bmi  diabetes pedigree  age  diabetes
# 0        0  33.6              0.627   50      True
# 1        0  26.6              0.351   31     False
# 2        0  23.3              0.672   32      True
# 3       94  28.1              0.167   21     False
# 4      168  43.1              2.288   33      True

# %%
df1.shape
# Out:
# (768, 9)

# %%
#insulin
df1[df1['insulin']==0]['insulin'].value_counts()
# Out:
# 0    374
# Name: insulin, dtype: int64

# %%
a= df1['insulin'].mean()
a
# Out:
# 79.79947916666667

# %%
b=df1['insulin'].median()
b
# Out:
# 30.5

# %%
#we chose mean

# %%
df1[df1['pregnancies']==0]['pregnancies'].value_counts()
# Out:
# 0    111
# Name: pregnancies, dtype: int64

# %%
c = df1['pregnancies'].mean()
c
# Out:
# 3.8450520833333335

# %%
d=df1['pregnancies'].median()
d
# Out:
# 3.0

# %%
df1[df1['plasma glucose']==0]['plasma glucose'].value_counts()
# Out:
# 0    5
# Name: plasma glucose, dtype: int64

# %%
e=df1['plasma glucose'].mean()
e
# Out:
# 120.89453125

# %%
f=df1['plasma glucose'].median()
f
# Out:
# 117.0

# %%
df1[df1['blood pressure']==0]['blood pressure'].value_counts()
# Out:
# 0    35
# Name: blood pressure, dtype: int64

# %%
g =df1['blood pressure'].mean()
g
# Out:
# 69.10546875

# %%
h=df1['blood pressure'].median()
h
# Out:
# 72.0

# %%
df1[df1['triceps skin thickness']==0]['triceps skin thickness'].value_counts()
# Out:
# 0    227
# Name: triceps skin thickness, dtype: int64

# %%
i=df1['triceps skin thickness'].mean()
i
# Out:
# 20.536458333333332

# %%
j=df1['triceps skin thickness'].median()
j
# Out:
# 23.0

# %%
df1[df1['bmi']==0]['bmi'].value_counts()
# Out:
# 0.0    11
# Name: bmi, dtype: int64

# %%
k=df1['bmi'].mean()
k
# Out:
# 31.992578124999977

# %%
l=df1['bmi'].median()
l
# Out:
# 32.0

# %%
df1[df1['age']==0]['age'].value_counts()
# Out:
# Series([], Name: age, dtype: int64)

# %%
df1['insulin'].replace(0,value=a,inplace=True)

# %%
df1.head()
# Out:
#    pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0            6             148              72                      35
# 1            1              85              66                      29
# 2            8             183              64                       0
# 3            1              89              66                      23
# 4            0             137              40                      35
#
#       insulin   bmi  diabetes pedigree  age  diabetes
# 0   79.799479  33.6              0.627   50      True
# 1   79.799479  26.6              0.351   31     False
# 2   79.799479  23.3              0.672   32      True
# 3   94.000000  28.1              0.167   21     False
# 4  168.000000  43.1              2.288   33      True

# %%
df1['pregnancies'].replace(0,value = c,inplace=True)

# %%
df1.head()
# Out:
#    pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0     6.000000             148              72                      35
# 1     1.000000              85              66                      29
# 2     8.000000             183              64                       0
# 3     1.000000              89              66                      23
# 4     3.845052             137              40                      35
#
#       insulin   bmi  diabetes pedigree  age  diabetes
# 0   79.799479  33.6              0.627   50      True
# 1   79.799479  26.6              0.351   31     False
# 2   79.799479  23.3              0.672   32      True
# 3   94.000000  28.1              0.167   21     False
# 4  168.000000  43.1              2.288   33      True

# %%
df1['plasma glucose'].replace(0,value=e,inplace=True)

# %%
df1['plasma glucose'][75]
# Out:
# 120.89453125

# %%
df1['blood pressure'].replace(0,value=g,inplace=True)

# %%
df1['blood pressure'][7]
# Out:
# 69.10546875

# %%
df1['triceps skin thickness'].replace(0,value=j,inplace=True)

# %%
df1['bmi'].replace(0,value=k,inplace=True)

# %%
df1.head()
# Out:
#    pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0     6.000000           148.0            72.0                      35
# 1     1.000000            85.0            66.0                      29
# 2     8.000000           183.0            64.0                      23
# 3     1.000000            89.0            66.0                      23
# 4     3.845052           137.0            40.0                      35
#
#       insulin   bmi  diabetes pedigree  age  diabetes
# 0   79.799479  33.6              0.627   50      True
# 1   79.799479  26.6              0.351   31     False
# 2   79.799479  23.3              0.672   32      True
# 3   94.000000  28.1              0.167   21     False
# 4  168.000000  43.1              2.288   33      True

# %%
df1.tail()
# Out:
#      pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 763         10.0           101.0            76.0                      48
# 764          2.0           122.0            70.0                      27
# 765          5.0           121.0            72.0                      23
# 766          1.0           126.0            60.0                      23
# 767          1.0            93.0            70.0                      31
#
#         insulin   bmi  diabetes pedigree  age  diabetes
# 763  180.000000  32.9              0.171   63     False
# 764   79.799479  36.8              0.340   27     False
# 765  112.000000  26.2              0.245   30     False
# 766   79.799479  30.1              0.349   47      True
# 767   79.799479  30.4              0.315   23     False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# pregnancies               768 non-null float64
# plasma glucose            768 non-null float64
# blood pressure            768 non-null float64
# triceps skin thickness    768 non-null int64
# insulin                   768 non-null float64
# bmi                       768 non-null float64
# diabetes pedigree         768 non-null float64
# age                       768 non-null int64
# diabetes                  768 non-null bool
# dtypes: bool(1), float64(6), int64(2)
# memory usage: 48.8 KB

# %%
df1.describe()
# Out:
#        pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# count   768.000000      768.000000      768.000000              768.000000
# mean      4.400782      121.681605       72.254807               27.334635
# std       2.984162       30.436016       12.115932                9.229014
# min       1.000000       44.000000       24.000000                7.000000
# 25%       2.000000       99.750000       64.000000               23.000000
# 50%       3.845052      117.000000       72.000000               23.000000
# 75%       6.000000      140.250000       80.000000               32.000000
# max      17.000000      199.000000      122.000000               99.000000
#
#           insulin         bmi  diabetes pedigree         age
# count  768.000000  768.000000         768.000000  768.000000
# mean   118.660163   32.450805           0.471876   33.240885
# std     93.080358    6.875374           0.331329   11.760232
# ...

# %%
df1.corr()
# Out:
#                         pregnancies  plasma glucose  blood pressure  \
# pregnancies                1.000000        0.152568        0.253275
# plasma glucose             0.152568        1.000000        0.219666
# blood pressure             0.253275        0.219666        1.000000
# triceps skin thickness     0.068421        0.172361        0.152458
# insulin                   -0.016738        0.396597        0.010926
# bmi                        0.097663        0.231478        0.281231
# diabetes pedigree         -0.010297        0.137106        0.000371
# age                        0.525261        0.266600        0.326740
# diabetes                   0.247971        0.492908        0.162986
#
#                         triceps skin thickness   insulin       bmi  \
# pregnancies                           0.068421 -0.016738  0.097663
# plasma glucose                        0.172361  0.396597  0.231478
# blood pressure                        0.152458  0.010926  0.281231
# ...

# %%
df1[df1['diabetes']==True]['diabetes'].value_counts()
# Out:
# True    268
# Name: diabetes, dtype: int64

# %%
df1[df1['diabetes']==False]['diabetes'].value_counts()
# Out:
# False    500
# Name: diabetes, dtype: int64

# %%
diabetes_map={True:1,False:0}

# %%
df1["diabetes"]=df1["diabetes"].map(diabetes_map)

# %%
df1.head(5)
# Out:
#    pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0     6.000000           148.0            72.0                      35
# 1     1.000000            85.0            66.0                      29
# 2     8.000000           183.0            64.0                      23
# 3     1.000000            89.0            66.0                      23
# 4     3.845052           137.0            40.0                      35
#
#       insulin   bmi  diabetes pedigree  age  diabetes
# 0   79.799479  33.6              0.627   50         1
# 1   79.799479  26.6              0.351   31         0
# 2   79.799479  23.3              0.672   32         1
# 3   94.000000  28.1              0.167   21         0
# 4  168.000000  43.1              2.288   33         1

# %%
df1.rename(columns={"plasma glucose":'glucose',"blood pressure":'bp','triceps skin thickness':'triceps_skin_thickness',
                    'diabetes pedigree':'diabetes_pedigree'},inplace=True)

# %%
df1.head(5)
# Out:
#    pregnancies  glucose    bp  triceps_skin_thickness     insulin   bmi  \
# 0     6.000000    148.0  72.0                      35   79.799479  33.6
# 1     1.000000     85.0  66.0                      29   79.799479  26.6
# 2     8.000000    183.0  64.0                      23   79.799479  23.3
# 3     1.000000     89.0  66.0                      23   94.000000  28.1
# 4     3.845052    137.0  40.0                      35  168.000000  43.1
#
#    diabetes_pedigree  age  diabetes
# 0              0.627   50         1
# 1              0.351   31         0
# 2              0.672   32         1
# 3              0.167   21         0
# 4              2.288   33         1

# %%
dia1 = df1[df1["diabetes"]==1]
dia1.head()
# Out:
#    pregnancies  glucose    bp  triceps_skin_thickness     insulin   bmi  \
# 0     6.000000    148.0  72.0                      35   79.799479  33.6
# 2     8.000000    183.0  64.0                      23   79.799479  23.3
# 4     3.845052    137.0  40.0                      35  168.000000  43.1
# 6     3.000000     78.0  50.0                      32   88.000000  31.0
# 8     2.000000    197.0  70.0                      45  543.000000  30.5
#
#    diabetes_pedigree  age  diabetes
# 0              0.627   50         1
# 2              0.672   32         1
# 4              2.288   33         1
# 6              0.248   26         1
# 8              0.158   53         1

# %%
dia0 = df1[df1['diabetes']==0]
dia0.head()
# Out:
#     pregnancies  glucose         bp  triceps_skin_thickness    insulin   bmi  \
# 1           1.0     85.0  66.000000                      29  79.799479  26.6
# 3           1.0     89.0  66.000000                      23  94.000000  28.1
# 5           5.0    116.0  74.000000                      23  79.799479  25.6
# 7          10.0    115.0  69.105469                      23  79.799479  35.3
# 10          4.0    110.0  92.000000                      23  79.799479  37.6
#
#     diabetes_pedigree  age  diabetes
# 1               0.351   31         0
# 3               0.167   21         0
# 5               0.201   30         0
# 7               0.134   29         0
# 10              0.191   30         0

# %%
sns.countplot(x=df1.diabetes)
plt.title("Count Plot for Outcome")
# Out:
# Text(0.5, 1.0, 'Count Plot for Outcome')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1,2,1)
sns.set_style("dark")
plt.title("people have Diabetes")
sns.distplot(dia1.pregnancies,kde=True)

plt.subplot(1,2,2)
sns.set_style("dark")
plt.title("people doesn't have Diabetes ")
sns.distplot(dia0.pregnancies,kde=True)

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1,2,1)
sns.set_style("dark")
plt.title("people have Diabetes ")
sns.distplot(dia1.insulin,kde=True)

plt.subplot(1,2,2)
sns.set_style("dark")
plt.title("people doesn't have Diabetes ")
sns.distplot(dia0.insulin,kde=True)

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1,2,1)
sns.set_style("dark")
plt.title("Histogram for glucose ")
sns.distplot(df1.insulin,kde=True)
